# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#For python environment : 
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import seaborn as sns

# %% [markdown]
# 1. Load the dataset and describe its detailed information: (size, shape, datatypes etc.)

# %%
df = pd.read_csv('Datasets/supermarket_sales.csv',sep=',')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.size
# Out:
# 17000

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %% [markdown]
# 2. Change the datatype of ‘Date’ to datetime format.

# %%
from datetime import date

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# ...

# %% [markdown]
# 3. Find the duration when the maximum number of quantity sold using lineplot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install mylib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Using legacy 'setup.py install' for mylib, since package 'wheel' is not installed.
# ...
#   Running setup.py install for mylib: started
#   Running setup.py install for mylib: finished with status 'done'
# ...

# %%
from matplotlib import pyplot
a4_dims = (11.7,8.27)
df['year'] = pd.DatetimeIndex(df['Date']).year
df['month'] = pd.DatetimeIndex(df['Date']).month
df[['month']]
fig, ax = pyplot.subplots(figsize=a4_dims)
Count = sns.lineplot(x="Date", y = 'Quantity' ,ax=ax, data = df)

# %% [markdown]
# Analysis: Maximum products were sold for the duration of 25 days

# %% [markdown]
# 4. Find the distribution of branch’s sales quantity per hour in a monthly fashion in function
# Gender type (Female / male) Use maximum parameters and allocate the proper value in them.

# %%
df['Hour'] = pd.DatetimeIndex(df['Time']).hour

sns.barplot(x="Hour", y="Quantity", hue="Gender", data=df).set_title("Sales quantity per hour")
# Out:
# Text(0.5, 1.0, 'Sales quantity per hour')

# %% [markdown]
# Analysis: Females maximum quantity sales is at 11,13 hours. Males maximum sales is in the hour at 14.

# %% [markdown]
# 5. Find the distribution of branch’s sales quantity per hour in a monthly fashion in function
# Customer type (member/normal) Use maximum parameters and allocate the proper value in
# them.

# %%
sns.barplot(x="month", y="Quantity", hue="Customer type", data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='Quantity'>

# %% [markdown]
# Analysis: maximum sales by member was in 3rd month and by normal people were in the 1st month.

# %% [markdown]
# 6. Plot the histogram for all the attributes and DRAW CONCLUSION

# %%
df.hist(bins=30, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'Unit price'}>,
#         <AxesSubplot:title={'center':'Quantity'}>,
#         <AxesSubplot:title={'center':'Tax 5%'}>],
#        [<AxesSubplot:title={'center':'Total'}>,
#         <AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'cogs'}>],
#        [<AxesSubplot:title={'center':'gross margin percentage'}>,
#         <AxesSubplot:title={'center':'gross income'}>,
#         <AxesSubplot:title={'center':'Rating'}>],
#        [<AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'month'}>,
#         <AxesSubplot:title={'center':'Hour'}>]], dtype=object)

# %% [markdown]
# 7. Show the counterplot for attribute Branch and draw the conclusion.

# %%
sns.countplot(x ='Branch', data = df)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %% [markdown]
# Analysis: Branch A is most busy

# %% [markdown]
# 8. Find mostly used payment method using countplot and write the analysis.

# %%
sns.countplot(x ='Payment', data = df)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %% [markdown]
# Analysis: E-wallet is most used payment method.

# %% [markdown]
# 9. Draw the boxplot between the attributes Branch and Ratings and draw the analysis.

# %%
sns.boxplot(x='Branch', y='Rating', data = df)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Rating'>

# %% [markdown]
# Analysis: Branch A and C is highly rated.

# %% [markdown]
# 10. Draw the boxenplot for finding the relation between the product line and quantity and draw
# the conclusion.

# %%
a4_dims = (11.7,8.27)
fig, ax = pyplot.subplots(figsize=a4_dims)
sns.boxenplot(x="Product line", y="Quantity",ax=ax ,data = df)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Quantity'>

# %% [markdown]
# Analysis: Fashion accessories were highly sold product line

# %% [markdown]
# 11. Draw the swarmplot and show the relation between features &#39;Customer type&#39; and &#39;Rating&#39;

# %%
sns.swarmplot(x='Customer type', y='Rating', data=df)
# Out:
# <AxesSubplot:xlabel='Customer type', ylabel='Rating'>

# %% [markdown]
# 12. Find the normal distribution, binomial distribution, poison distribution for the randomly
# generated 50 values and visualize it using distance plot.

# %%
from numpy import random
sns.distplot(random.normal(size=50), hist=True)
plt.show()
# Out:
# C:\Users\Harsh\AppData\Roaming\Python\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Visualization of Binomial Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.binomial(n=10, p=0.5, size=50), hist=True, kde=False)
plt.show()
# Out:
# C:\Users\Harsh\AppData\Roaming\Python\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Visualization of Poisson Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.poisson(lam=2, size=50), kde=False)

plt.show()

# %% [markdown]
# 13. Show the pairplot for the attributes such as gross income, quantity, unit price and ratings and
# DRAW CONCLUSION.

# %%
sns.pairplot(df, hue ='gross income')
plt.show()

# %%
sns.pairplot(df, hue ='Unit price')
plt.show()

# %%
sns.pairplot(df, hue ='Rating')
plt.show()

# %% [markdown]
# 14. Find the correlation between all the columns and represent it using heatmap.

# %%
data = df
correlation = data.corr(method='pearson')
print(correlation)
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
# year                            NaN       NaN       NaN       NaN       NaN
# month                     -0.027387 -0.014524 -0.022301 -0.022301 -0.022301
# Hour                       0.008242 -0.007317 -0.002770 -0.002770 -0.002770
#
# ...

# %%
sns.heatmap(np.round(df.corr(),2), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 15. Generate the following 3 Plots as an output by setting the suitable parameters in countplot.

# %%
a=sns.countplot(x ='Payment', data = df,hue = 'Branch')
a.set(title="Payment Channel by branch")
# Out:
# [Text(0.5, 1.0, 'Payment Channel by branch')]

# %%
b=sns.countplot(x ='Gender', data = df)
b.set(title="Gender_Count")
# Out:
# [Text(0.5, 1.0, 'Gender_Count')]

# %%
c=sns.barplot(x ='Quantity',y = 'Product line',data = df,hue = 'Payment')
c.set(title="Payment per Product line")
# Out:
# [Text(0.5, 1.0, 'Payment per Product line')]
