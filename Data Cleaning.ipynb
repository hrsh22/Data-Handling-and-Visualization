# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1) Load the Toyota vehicle’s data from a given csv file into a dataframe and print it. (Toyota.csv)

# %%
toyota_data=pd.read_csv('Datasets/Toyota.csv',sep=',',header='infer')

# %%
toyota_data
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
df2=toyota_data.copy()

# %% [markdown]
# 2) Replace all abnormal symbols such as ‘?’ ‘***’ etc. by Null values

# %%
toyota_data=pd.read_csv('Datasets/Toyota.csv',sep=',',header='infer' , na_values=('??','***'))
toyota_data
# Out:
#       Unnamed: 0  Price   Age       KM FuelType   HP  MetColor  Automatic  \
# 0              0  13500  23.0  46986.0   Diesel   90       1.0          0
# 1              1  13750  23.0  72937.0   Diesel   90       1.0          0
# 2              2  13950  24.0  41711.0   Diesel   90       NaN          0
# 3              3  14950  26.0  48000.0   Diesel   90       0.0          0
# 4              4  13750  30.0  38500.0   Diesel   90       0.0          0
# ...          ...    ...   ...      ...      ...  ...       ...        ...
# 1431        1431   7500   NaN  20544.0   Petrol   86       1.0          0
# 1432        1432  10845  72.0      NaN   Petrol   86       0.0          0
# 1433        1433   8500   NaN  17016.0   Petrol   86       0.0          0
# 1434        1434   7250  70.0      NaN      NaN   86       1.0          0
# 1435        1435   6950  76.0      1.0   Petrol  110       0.0          0
#
#         CC  Doors  Weight
# 0     2000  three    1165
# ...

# %% [markdown]
# 3) Count the total number of null values present in each attribute (column)

# %%
toyota_data.isnull()
# Out:
#       Unnamed: 0  Price    Age     KM  FuelType     HP  MetColor  Automatic  \
# 0          False  False  False  False     False  False     False      False
# 1          False  False  False  False     False  False     False      False
# 2          False  False  False  False     False  False      True      False
# 3          False  False  False  False     False  False     False      False
# 4          False  False  False  False     False  False     False      False
# ...          ...    ...    ...    ...       ...    ...       ...        ...
# 1431       False  False   True  False     False  False     False      False
# 1432       False  False  False   True     False  False     False      False
# 1433       False  False   True  False     False  False     False      False
# 1434       False  False  False   True      True  False     False      False
# 1435       False  False  False  False     False  False     False      False
#
#          CC  Doors  Weight
# 0     False  False   False
# ...

# %%
print(toyota_data.isnull().sum())
# Out:
# Unnamed: 0      0
# Price           0
# Age           100
# KM             15
# FuelType      100
# HP              0
# MetColor      150
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# dtype: int64

# %% [markdown]
# 4) Replace the NaN in Age column by median value.

# %%
x=toyota_data["Age"].median()
toyota_data["Age"].fillna(x,inplace=True)
toyota_data
# Out:
#       Unnamed: 0  Price   Age       KM FuelType   HP  MetColor  Automatic  \
# 0              0  13500  23.0  46986.0   Diesel   90       1.0          0
# 1              1  13750  23.0  72937.0   Diesel   90       1.0          0
# 2              2  13950  24.0  41711.0   Diesel   90       NaN          0
# 3              3  14950  26.0  48000.0   Diesel   90       0.0          0
# 4              4  13750  30.0  38500.0   Diesel   90       0.0          0
# ...          ...    ...   ...      ...      ...  ...       ...        ...
# 1431        1431   7500  60.0  20544.0   Petrol   86       1.0          0
# 1432        1432  10845  72.0      NaN   Petrol   86       0.0          0
# 1433        1433   8500  60.0  17016.0   Petrol   86       0.0          0
# 1434        1434   7250  70.0      NaN      NaN   86       1.0          0
# 1435        1435   6950  76.0      1.0   Petrol  110       0.0          0
#
#         CC  Doors  Weight
# 0     2000  three    1165
# ...

# %% [markdown]
# 5) Replace the string value in column Door with number.

# %%
a=list()
for i in toyota_data['Doors']:
  a.append(i)
set(a)
# Out:
# {'2', '3', '4', '5', 'five', 'four', 'three'}

# %%
toyota_data["Doors"].replace({'five':5,'four':4,'three':3,'2':2,'3':3,'4':4,'5':5},inplace=True)
toyota_data
# Out:
#       Unnamed: 0  Price   Age       KM  FuelType   HP  MetColor  Automatic  \
# 0              0  13500  23.0  46986.0         1   90       1.0          0
# 1              1  13750  23.0  72937.0         1   90       1.0          0
# 2              2  13950  24.0  41711.0         1   90       1.0          0
# 3              3  14950  26.0  48000.0         1   90       0.0          0
# 4              4  13750  30.0  38500.0         1   90       0.0          0
# ...          ...    ...   ...      ...       ...  ...       ...        ...
# 1431        1431   7500  60.0  20544.0         0   86       1.0          0
# 1432        1432  10845  72.0      NaN         0   86       0.0          0
# 1433        1433   8500  60.0  17016.0         0   86       0.0          0
# 1434        1434   7250  70.0      NaN         0   86       1.0          0
# 1435        1435   6950  76.0      1.0         0  110       0.0          0
#
#         CC  Doors  Weight
# 0     2000      3    1165
# ...

# %%
toyota_data["Doors"].value_counts()
# Out:
# 5    674
# 3    622
# 4    138
# 2      2
# Name: Doors, dtype: int64

# %% [markdown]
# 6) Returns a Series containing counts of unique values for column ‘FuelType’ (Petrol,
# Diesel, CNG )

# %%
toyota_data["FuelType"].unique()
# Out:
# array(['Diesel', nan, 'Petrol', 'CNG'], dtype=object)

# %%
toyota_data["FuelType"].value_counts()
# Out:
# Petrol    1177
# Diesel     144
# CNG         15
# Name: FuelType, dtype: int64

# %% [markdown]
# 7) Get the mode value of FuelType and fill NA/NaN values using the specified value of
# mode.

# %%
m=toyota_data["FuelType"].mode()[0]
print(m)
toyota_data["FuelType"].fillna(m,inplace=True)
toyota_data
# Out:
# Petrol
#       Unnamed: 0  Price   Age       KM FuelType   HP  MetColor  Automatic  \
# 0              0  13500  23.0  46986.0   Diesel   90       1.0          0
# 1              1  13750  23.0  72937.0   Diesel   90       1.0          0
# 2              2  13950  24.0  41711.0   Diesel   90       NaN          0
# 3              3  14950  26.0  48000.0   Diesel   90       0.0          0
# 4              4  13750  30.0  38500.0   Diesel   90       0.0          0
# ...          ...    ...   ...      ...      ...  ...       ...        ...
# 1431        1431   7500  60.0  20544.0   Petrol   86       1.0          0
# 1432        1432  10845  72.0      NaN   Petrol   86       0.0          0
# 1433        1433   8500  60.0  17016.0   Petrol   86       0.0          0
# 1434        1434   7250  70.0      NaN   Petrol   86       1.0          0
# 1435        1435   6950  76.0      1.0   Petrol  110       0.0          0
#
#         CC Doors  Weight
# 0     2000     3    1165
# ...

# %% [markdown]
# 8) Get the mode value of Metcolor and fill NA/NaN values using the specified value of mode.

# %%
n=toyota_data["MetColor"].mode()[0]
print(n)
toyota_data["MetColor"].fillna(n,inplace=True)
toyota_data
# Out:
# 1.0
#       Unnamed: 0  Price   Age       KM FuelType   HP  MetColor  Automatic  \
# 0              0  13500  23.0  46986.0   Diesel   90       1.0          0
# 1              1  13750  23.0  72937.0   Diesel   90       1.0          0
# 2              2  13950  24.0  41711.0   Diesel   90       1.0          0
# 3              3  14950  26.0  48000.0   Diesel   90       0.0          0
# 4              4  13750  30.0  38500.0   Diesel   90       0.0          0
# ...          ...    ...   ...      ...      ...  ...       ...        ...
# 1431        1431   7500  60.0  20544.0   Petrol   86       1.0          0
# 1432        1432  10845  72.0      NaN   Petrol   86       0.0          0
# 1433        1433   8500  60.0  17016.0   Petrol   86       0.0          0
# 1434        1434   7250  70.0      NaN   Petrol   86       1.0          0
# 1435        1435   6950  76.0      1.0   Petrol  110       0.0          0
#
#         CC Doors  Weight
# 0     2000     3    1165
# ...

# %% [markdown]
# 9) Replace the value of FuelType as for Petrol replaces with 0, diesel with 1 and CNG with
# 2.

# %%
toyota_data["FuelType"].replace({'Petrol':0,'Diesel':1, 'CNG':2},inplace=True) 
toyota_data
# Out:
#       Unnamed: 0  Price   Age       KM  FuelType   HP  MetColor  Automatic  \
# 0              0  13500  23.0  46986.0         1   90       1.0          0
# 1              1  13750  23.0  72937.0         1   90       1.0          0
# 2              2  13950  24.0  41711.0         1   90       1.0          0
# 3              3  14950  26.0  48000.0         1   90       0.0          0
# 4              4  13750  30.0  38500.0         1   90       0.0          0
# ...          ...    ...   ...      ...       ...  ...       ...        ...
# 1431        1431   7500  60.0  20544.0         0   86       1.0          0
# 1432        1432  10845  72.0      NaN         0   86       0.0          0
# 1433        1433   8500  60.0  17016.0         0   86       0.0          0
# 1434        1434   7250  70.0      NaN         0   86       1.0          0
# 1435        1435   6950  76.0      1.0         0  110       0.0          0
#
#         CC Doors  Weight
# 0     2000     3    1165
# ...

# %% [markdown]
# 10) Copy the dataset to new dataframe and apply One hot encoding categorical approach on
# Fueltype column.

# %%
df=pd.DataFrame(toyota_data['FuelType'])
df
# Out:
#       FuelType
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 1431         0
# 1432         0
# 1433         0
# 1434         0
# 1435         0
#
# [1436 rows x 1 columns]

# %%
y = pd.get_dummies(df.FuelType, prefix='FuelType')
y
# Out:
#       FuelType_0  FuelType_1  FuelType_2
# 0              0           1           0
# 1              0           1           0
# 2              0           1           0
# 3              0           1           0
# 4              0           1           0
# ...          ...         ...         ...
# 1431           1           0           0
# 1432           1           0           0
# 1433           1           0           0
# 1434           1           0           0
# 1435           1           0           0
#
# [1436 rows x 3 columns]

# %% [markdown]
# 11) Apply Binary Encoding approach to Fueltype column:

# %%
df2
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
df2["FuelType"].unique()
# Out:
# array(['Diesel', nan, 'Petrol', 'CNG'], dtype=object)

# %%
pip install category_encoders

# %%
import category_encoders as ce

# %%
encoder = ce.BinaryEncoder(cols=['FuelType'])
df_binary = encoder.fit_transform(df2)

df_binary
# Out:
#       Unnamed: 0  Price   Age     KM  FuelType_0  FuelType_1  FuelType_2   HP  \
# 0              0  13500  23.0  46986           0           0           1   90
# 1              1  13750  23.0  72937           0           0           1   90
# 2              2  13950  24.0  41711           0           0           1   90
# 3              3  14950  26.0  48000           0           0           1   90
# 4              4  13750  30.0  38500           0           0           1   90
# ...          ...    ...   ...    ...         ...         ...         ...  ...
# 1431        1431   7500   NaN  20544           0           1           1   86
# 1432        1432  10845  72.0     ??           0           1           1   86
# 1433        1433   8500   NaN  17016           0           1           1   86
# 1434        1434   7250  70.0     ??           0           1           0   86
# 1435        1435   6950  76.0      1           0           1           1  110
#
# ...

# %% [markdown]
# 12) Check for missing data after filling values

# %%
mean=toyota_data['KM'].mean()
print(mean)
toyota_data['KM'].fillna(mean,inplace=True)
toyota_data
# Out:
# 68647.23997185081
#       Unnamed: 0  Price   Age            KM  FuelType   HP  MetColor  \
# 0              0  13500  23.0  46986.000000         1   90       1.0
# 1              1  13750  23.0  72937.000000         1   90       1.0
# 2              2  13950  24.0  41711.000000         1   90       1.0
# 3              3  14950  26.0  48000.000000         1   90       0.0
# 4              4  13750  30.0  38500.000000         1   90       0.0
# ...          ...    ...   ...           ...       ...  ...       ...
# 1431        1431   7500  60.0  20544.000000         0   86       1.0
# 1432        1432  10845  72.0  68647.239972         0   86       0.0
# 1433        1433   8500  60.0  17016.000000         0   86       0.0
# 1434        1434   7250  70.0  68647.239972         0   86       1.0
# 1435        1435   6950  76.0      1.000000         0  110       0.0
#
#       Automatic    CC  Doors  Weight
# 0             0  2000      3    1165
# 1             0  2000      3    1165
# ...

# %%
toyota_data.isnull().sum()
# Out:
# Unnamed: 0    0
# Price         0
# Age           0
# KM            0
# FuelType      0
# HP            0
# MetColor      0
# Automatic     0
# CC            0
# Doors         0
# Weight        0
# dtype: int64
